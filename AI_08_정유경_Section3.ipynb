# %% [markdown]
# <a href="https://colab.research.google.com/github/yk-Jeong/Codestates_Project/blob/main/AI_08_%EC%A0%95%EC%9C%A0%EA%B2%BD_Section3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# %% [markdown]
# 데이터 수집: https://www.thecocktaildb.com/api/json/v1/1/search.php?f=a~z, 0~9
#
# https://www.kaggle.com/ai-first/cocktail-ingredients (

# %% [markdown]
# ####데이터 수집

# %%
import string

num = list(range(10))
alphabet = list(string.ascii_lowercase)
list1 = alphabet + num

for i in list1:
  url = f'https://www.thecocktaildb.com/api/json/v1/1/search.php?f={i}'
  print(url)

# %%
import json
from pandas import json_normalize

# %%
with open('mergeddata.txt', 'r') as f:
  data = json.load(f)
data = json_normalize(data['drinks'])

# %% [markdown]
# #### 일단 중단

# %%
df = pd.read_csv("all_drinks.csv")

# %%
df
# Out:
#      Unnamed: 0                              strDrink  ... strMeasure9  strVideo
# 0             0  '57 Chevy with a White License Plate  ...         NaN       NaN
# 1             1                        1-900-FUK-MEUP  ...                   NaN
# 2             2                      110 in the shade  ...         NaN       NaN
# 3             3                151 Florida Bushwacker  ...                   NaN
# 4             4                           155 Belmont  ...                   NaN
# ..          ...                                   ...  ...         ...       ...
# 541         541                       Zippy's Revenge  ...         NaN       NaN
# 542         542                        Zizi Coin-coin  ...          \n       NaN
# 543         543                                Zoksel  ...          \n       NaN
# 544         544                             Zorbatini  ...         NaN       NaN
# 545         545                                 Zorro  ...         NaN       NaN
#
# [546 rows x 41 columns]

# %%
df['strIngredient3'].unique()
# Out:
# array(['Lemon Juice', 'Cognac', 'Heavy cream', 'Grenadine', 'Tonic water',
#        None, 'Cranberry juice', 'Apple juice', 'Orange juice',
#        'Egg white', 'Lime juice', 'Dry Vermouth', 'Lemon juice',
#        'maraschino liqueur', 'Light cream', 'Pineapple juice',
#        'Blackberry brandy', 'Bitters', 'Soda water', 'Frangelico'],
#       dtype=object)

# %% [markdown]
# 필요 없는 컬럼: dateModified, Unnamed: 0,

# %%
df = df.drop(['dateModified', 'Unnamed: 0'], axis=1)
df
# Out:
#                                  strDrink  idDrink  ... strMeasure9 strVideo
# 0    '57 Chevy with a White License Plate    14029  ...         NaN      NaN
# 1                          1-900-FUK-MEUP    15395  ...                  NaN
# 2                        110 in the shade    15423  ...         NaN      NaN
# 3                  151 Florida Bushwacker    14588  ...                  NaN
# 4                             155 Belmont    15346  ...                  NaN
# ..                                    ...      ...  ...         ...      ...
# 541                       Zippy's Revenge    14065  ...         NaN      NaN
# 542                        Zizi Coin-coin    14594  ...          \n      NaN
# 543                                Zoksel    15691  ...          \n      NaN
# 544                             Zorbatini    16963  ...         NaN      NaN
# 545                                 Zorro    15328  ...         NaN      NaN
#
# [546 rows x 39 columns]

# %%
df['strIBA'].unique()
# Out:
# array([nan, 'Unforgettables', 'New Era Drinks', 'Contemporary Classics'],
#       dtype=object)

# %%
import pandas_profiling

# %%
pip install pandas-profiling==2.11.0 --upgrade

# %% [markdown]
# 난제
#
# - thecocktaildb에 업데이트가 생길 때마다 자동으로 긁어올 수는 없을까
# - 가중치를 줘서 계산할 수 없을까?
