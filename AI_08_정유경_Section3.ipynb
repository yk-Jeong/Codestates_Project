# %% [markdown]
# <a href="https://colab.research.google.com/github/yk-Jeong/Codestates_Project/blob/main/AI_08_%EC%A0%95%EC%9C%A0%EA%B2%BD_Section3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# %% [markdown]
# 데이터 수집: https://www.thecocktaildb.com/api/json/v1/1/search.php?f=a~z

# %%
import string
for i in string.ascii_lowercase:
  url = f'https://www.thecocktaildb.com/api/json/v1/1/search.php?f={i}'
  print(url)
# Out:
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=a
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=b
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=c
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=d
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=e
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=f
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=g
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=h
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=i
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=j
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=k
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=l
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=m
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=n
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=o
# https://www.thecocktaildb.com/api/json/v1/1/search.php?f=p
# ...

# %%
import json
from pandas import json_normalize

# %%
with open('merged.txt', 'r') as f:
  data = json.load(f)
df = json_normalize(data['drinks'])

# %%
df.sort_values('dateModified', ascending=False).head(22)
# Out:
#     idDrink  ...         dateModified
# 379   17826  ...  2018-09-01 10:34:38
# 57    17830  ...  2018-06-27 15:15:09
# 283   17829  ...  2018-03-24 00:58:16
# 358   17828  ...  2018-03-22 23:33:30
# 263   17827  ...  2018-03-22 23:23:30
# 39    17825  ...  2018-02-18 09:50:01
# 372   17824  ...  2018-02-04 12:46:52
# 271   17266  ...  2018-01-12 21:31:33
# 243   17256  ...  2017-12-19 18:34:15
# 128   17255  ...  2017-12-19 18:14:32
# 27    17254  ...  2017-12-19 18:09:45
# 140   17252  ...  2017-12-19 18:05:32
# 275   17253  ...  2017-12-19 17:59:53
# 72    17250  ...  2017-12-19 17:25:34
# 279   17249  ...  2017-12-19 17:18:23
# 115   17248  ...  2017-12-19 17:06:07
# 371   17247  ...  2017-12-19 16:57:04
# 102   17246  ...  2017-12-18 11:11:49
# 322   17245  ...  2017-12-04 16:55:43
# 326   12091  ...  2017-11-27 11:28:14
# 410   17241  ...  2017-11-01 17:35:26
# 158   17239  ...  2017-11-01 17:18:32
#
# [22 rows x 51 columns]

# %%
df['strIngredient1'].unique()
# Out:
# array(['Gin', 'Amaretto', 'Dark rum', 'Absolut Vodka', '151 proof rum',
#        'Applejack', 'Strawberry schnapps', 'Orange juice', 'Vodka',
#        'Light rum', 'Scotch', 'Blended whiskey', 'Dry Vermouth',
#        'Sweet Vermouth', 'Grenadine', 'Kahlua'], dtype=object)

# %%
df['strIngredient2'].unique()
# Out:
# array(['Grand Marnier', 'Baileys irish cream', 'Grenadine', 'Lemon juice',
#        'Gin', 'Wild Turkey', 'Grapefruit juice', 'Orange juice',
#        'Pisang Ambon', 'Peach nectar', 'Kahlua', 'Vermouth', 'Triple sec',
#        'Sweet Vermouth', 'lemon juice', 'Creme de Cacao', 'Dry Vermouth',
#        'Bourbon', 'Lime juice', 'Creme de Banane'], dtype=object)

# %%
df['strIngredient3'].unique()
# Out:
# array(['Lemon Juice', 'Cognac', 'Heavy cream', 'Grenadine', 'Tonic water',
#        None, 'Cranberry juice', 'Apple juice', 'Orange juice',
#        'Egg white', 'Lime juice', 'Dry Vermouth', 'Lemon juice',
#        'maraschino liqueur', 'Light cream', 'Pineapple juice',
#        'Blackberry brandy', 'Bitters', 'Soda water', 'Frangelico'],
#       dtype=object)

# %% [markdown]
# #### 일단 중단

# %%
df2 = pd.read_csv("all_drinks.csv")

# %%
df2.sort_values('dateModified', ascending=False)
# Out:
#      Unnamed: 0              strDrink  ... strMeasure9  strVideo
# 454         454           Scotch Sour  ...                   NaN
# 447         447             Salty Dog  ...         NaN       NaN
# 498         498           Texas Sling  ...                   NaN
# 448         448         San Francisco  ...         NaN       NaN
# 497         497     Texas Rattlesnake  ...                   NaN
# ..          ...                   ...  ...         ...       ...
# 362         362             Margarita  ...         NaN       NaN
# 483         483  Strawberry Margarita  ...          \n       NaN
# 168         168        Brandy Cobbler  ...                   NaN
# 228         228     Dubonnet Cocktail  ...                   NaN
# 227         227           Dry Rob Roy  ...         NaN       NaN
#
# [546 rows x 41 columns]

# %%
#df2 = pd.read_csv("mr-boston-flattened.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-878357169082> in <module>()
# ----> 1 df2 = pd.read_csv("mr-boston-flattened.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# 필요 없는 컬럼: dateModified,

# %%
df = df.drop('dateModified', axis=1)
df = df.drop('Unnamed: 0', axis=1)
df

# %%
df['strCategory'].unique()

# %%
df['strIngredient4'].unique() is df['strIngredient2'].unique() #컬럼명 바꾸어가며 확인하였으나 같지 않음

# %%
df['strIngredient11'].unique() #갈수록 unique 값이 줄어드는 것을 확인할 수 있음

# %% [markdown]
# 가중치를 줘서 계산할 수 없을까?

# %%
df2

# %%
df2['name'].sort_values(ascending=True)

# %%
 df['strDrink'].sort_values(ascending=True)
